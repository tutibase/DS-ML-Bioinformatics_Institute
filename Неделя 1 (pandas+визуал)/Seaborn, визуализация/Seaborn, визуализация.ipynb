# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('dark_background')

# %%
students_performance = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
#students_performance = pd.read_csv('StudentsPerformance.csv')

# переименование индексов колонок
students_performance = students_performance\
                                    .rename(columns=
                                            {'parental level of education': 'parental_level_of_education',
                                            'test preparation course': 'test_preparation_course',
                                            'math score': 'math_score',
                                            'reading score': 'reading_score',
                                            'writing score': 'writing_score'})

students_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# гистограмма pandas (но через библиотеку matplotlib)
students_performance.math_score.hist()
# Out:
# <Axes: >

# %%
# 
students_performance.plot.scatter(x='math_score', y='reading_score')
# Out:
# <Axes: xlabel='math_score', ylabel='reading_score'>

# %%
# seaborn визуализация
# fir_reg - реагрессионная прямая
# hue - по какому признаку разделить
ax = sns.lmplot(x='math_score', y='reading_score', hue = 'gender', data = students_performance, fit_reg=False)
ax.set_xlabels('Math score')
ax.set_ylabels('Reading score')

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# ## Примеры решений

# %%
# варианты построения одного графика
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')
# df = pd.read_csv('income.csv')

# %%
df.head()
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
df['income'].plot()
# Out:
# <Axes: >

# %%
df.plot(kind='line')
# Out:
# <Axes: >

# %%
df.plot()
# Out:
# <Axes: >

# %%
sns.lineplot(x=df.index, y=df.income)
# Out:
# <Axes: ylabel='income'>

# %%
sns.lineplot(data=df)
# Out:
# <Axes: >

# %%
plt.plot(df.index, df.income)

# %%
df.income.plot()
# Out:
# <Axes: >

# %%
# построение кластеров


df = pd.read_csv('dataset_209770_6.txt', sep=" ")
df.head()
# Out:
#              x            y
# 0  1285.265950   991.653822
# 1   112.354440   114.374377
# 2   792.589941  1313.138477
# 3   712.060728   900.185992
# 4   407.715204  1093.439458

# %%
df.plot.scatter(x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
# тепловая карта

df = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv', index_col = 0)
#df = pd.read_csv('genome_matrix.csv', index_col = 0)
df.head()
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(data=df, cmap="viridis")
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
# подсчет моды количества ролей у героев


dota = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')
# dota = pd.read_csv('dota_hero_stats.csv')
dota.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
lenths = [len(r.split(',')) for r in dota.roles]
dota['lenths'] = lenths
dota.lenths.mode()
# Out:
# 0    4
# Name: lenths, dtype: int64

# %%
sns.distplot([x.count(',')+1 for x in dota.roles], bins=15)
# Out:
# C:\Users\dykun\AppData\Local\Temp\ipykernel_2916\3022657529.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([x.count(',')+1 for x in dota.roles], bins=15)
# <Axes: ylabel='Density'>

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv', index_col=0)
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
sns.pairplot(df,  vars=df.columns[:-1], diag_kind='kde')

# %%
for column in df:
    sns.kdeplot(df[str(column)])

# %%
for column in df:
    sns.displot(df, x=column, kde=True)

# %%
fl = df.describe().T
fl['diff'] = fl['max']-fl['min']
fl
# Out:
#               count      mean       std  min  25%   50%  75%  max  diff
# sepal length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9   3.6
# sepal width   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4   2.4
# petal length  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9   5.9
# petal width   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5   2.4
# species       150.0  1.000000  0.819232  0.0  0.0  1.00  2.0  2.0   2.0

# %%
sns.violinplot(data = df)
# Out:
# <Axes: >

# %%
sns.violinplot(y='petal length', data=df)
# Out:
# <Axes: ylabel='petal length'>

# %%
df.corr()
# Out:
#               sepal length  sepal width  petal length  petal width   species
# sepal length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000
